# %%
using DifferentialEquations, SciMLBase, Plots, Random # for solving ODEs
using QuasiMonteCarlo # for LHS
using XLSX, CSV, DataFrames, Tables # for post-processing
using Optimization, OptimizationOptimJL, LineSearches # for optimization
using Trapz	 

include("C:/Users/20192809/Documents/GitHub/Master-thesis/MMmodel/Including.jl")
include("./Data/PREDICT.jl")

# set Random seed for reproducibility
Random.seed!(1234);

# Data from PREDICT
data = PREDICT_data();
meal_G = 86000.0
meal_TG = 53000.0
BW = 72.88
time_G = [0,15,30,60,120,180,240]
time_I = [0,15,30,60,120,240]
time_TG = [0,60,120,180,240];

# %%
glucose = Matrix(data[:,2:8]);
insulin = Matrix(data[:,9:14]);
TG = Matrix(data[:,15:19]);

# estimated parameters
estimated_parameters = ["k1","k5","k6","k11","tau_LPL","k14","k16"] 
ub = [0.05, 1.5, 10., 1., 720., 0.1, 1.]
lb = [0.005, 0, 0, 0, 60.0, 0.005, 0];

# %%
results =[]
for i in axes(glucose,2)
    result = ParameterEstimation(glucose[i,:], insulin[i,:], TG[i,:], BW, meal_G, meal_TG, time_G, time_I, time_TG, estimated_params = estimated_parameters, ub = ub, lb = lb, save_boolean = false, save_path = "./Data/PREDICT_fits.CSV")
    push!(results, result)
end
# Out:
# Parameter estimation done!
# Parameter estimation done!
# Parameter estimation done!
# ┌ Warning: Interrupted. Larger maxiters is needed. If you are using an integrator for non-stiff ODEs or an automatic switching algorithm (the default), you may want to consider using a method for stiff equations. See the solver pages for more details (e.g. https://docs.sciml.ai/DiffEqDocs/stable/solvers/ode_solve/#Stiff-Problems).
# └ @ SciMLBase C:\Users\20192809\.julia\packages\SciMLBase\Dwomw\src\integrator_interface.jl:600
# ...
